# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file= '/kaggle/input/anaemic-prediction/output.csv'
report= pd.read_csv(file)

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3  F      45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5  M      43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
report1= report['%Green pixel']
report1
# Out:
# 0      30.8421
# 1      28.1900
# 2      28.9677
# 3      28.9899
# 4      30.6972
#         ...
# 99     29.2860
# 100    30.6757
# 101    31.9084
# 102    29.2769
# 103    29.8094
# Name: %Green pixel, Length: 104, dtype: float64

# %%
#104 rows x 7 columns

# %%
a= len(report1)
b= sum(report1)
average= b/a
average
# Out:
# 28.87550673076924

# %%
s= report.max()

# %%
r= report.min()

# %%
s['%Green pixel'] #Highest
# Out:
# 32.3681

# %%
r['%Green pixel'] #Lowest
# Out:
# 25.1403

# %%
report2= report['Sex'].value_counts()
report2
# Out:
# Sex
# M     29
# M     26
# F     26
# F     23
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
graph= sns.distplot(report['%Green pixel'],  kde= False, bins=20)
# Out:
# /tmp/ipykernel_18/1122451276.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   graph= sns.distplot(report['%Green pixel'],  kde= False, bins=20)

# %%
sns.jointplot(x='%Green pixel', y='%Red Pixel', data= report, kind= 'kde')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(report, kind='scatter')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
report['Anaemic'].value_counts()
# Out:
# Anaemic
# No     78
# Yes    26
# Name: count, dtype: int64

# %%
sns.distplot(report1)
# Out:
# /tmp/ipykernel_18/3172829229.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(report1)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='%Green pixel', ylabel='Density'>

# %%
sns.pairplot(report,hue= 'Anaemic', palette='cool')
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.kdeplot(report['%Red Pixel'])
sns.rugplot(report['%Red Pixel'])
#sns.distplot(report['%Red Pixel'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='%Red Pixel', ylabel='Density'>

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3  F      45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5  M      43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
report1= report['%Green pixel']
report2= report['Number']

# %%
plt.plot(report1,report2, 'b');
plt.plot(report2,report1, 'b')

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3  F      45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5  M      43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
report_edit= report.drop('Sex', axis= 1)
report_edit
# Out:
#      Number  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1     43.2555       30.8421      25.9025   6.3     Yes
# 1         2     45.6033       28.1900      26.2067  13.5      No
# 2         3     45.0107       28.9677      26.0215  11.7      No
# 3         4     44.5398       28.9899      26.4703  13.5      No
# 4         5     43.2870       30.6972      26.0158  12.4      No
# ..      ...         ...           ...          ...   ...     ...
# 99      100     49.9999       29.2860      20.7141  14.5     Yes
# 100     101     42.2324       30.6757      27.0919   6.3     Yes
# 101     102     45.6064       31.9084      22.4852  12.7      No
# 102     103     45.2095       29.2769      25.5136  13.4      No
# 103     104     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 6 columns]

# %%
report_edit
# Out:
#      Number  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1     43.2555       30.8421      25.9025   6.3     Yes
# 1         2     45.6033       28.1900      26.2067  13.5      No
# 2         3     45.0107       28.9677      26.0215  11.7      No
# 3         4     44.5398       28.9899      26.4703  13.5      No
# 4         5     43.2870       30.6972      26.0158  12.4      No
# ..      ...         ...           ...          ...   ...     ...
# 99      100     49.9999       29.2860      20.7141  14.5     Yes
# 100     101     42.2324       30.6757      27.0919   6.3     Yes
# 101     102     45.6064       31.9084      22.4852  12.7      No
# 102     103     45.2095       29.2769      25.5136  13.4      No
# 103     104     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 6 columns]

# %%
sns.pairplot(report_edit)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.distplot(report['Hb'])
# Out:
# /tmp/ipykernel_18/2129399221.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(report['Hb'])
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Hb', ylabel='Density'>

# %%
sns.distplot(report['Number'])
# Out:
# /tmp/ipykernel_18/1978528782.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(report['Number'])
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Number', ylabel='Density'>

# %%
sns.displot(report['Hb'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(report['Hb'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Hb', ylabel='Count'>

# %%
x= report.Number
x
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 99     100
# 100    101
# 101    102
# 102    103
# 103    104
# Name: Number, Length: 104, dtype: int64

# %%
y= report['%Green pixel']
y
# Out:
# 0      30.8421
# 1      28.1900
# 2      28.9677
# 3      28.9899
# 4      30.6972
#         ...
# 99     29.2860
# 100    30.6757
# 101    31.9084
# 102    29.2769
# 103    29.8094
# Name: %Green pixel, Length: 104, dtype: float64

# %%
plt.plot(y,x, 'b*-')
plt.xlabel('Number')
plt.ylabel('%Green pixel')
# Out:
# Text(0, 0.5, '%Green pixel')

# %%
#count plot sshows the graph of discreet data(yes/no, aphabets)
#estimator is used to give what you want. either mean or SD or maax e.t.c.
#orient='h' Horizontal
#orient='v' Vertical
#hue in boxplot is to further evaluate your data
#violinplot is used to get the distribution plot as well as the box plot
#split=True is to join two discreet values together
#stripplot 
#Swarmplot is a scattered violin plot
#plots=
#.pivot table  allows you to choose what you want for the column, index, and values
#clustermap add the value subtract by its minimum and divide the total by the maximum value
#standard_scale= 1: where ! is for columns and 0 forr rows

# %%
sns.clustermap?

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3  F      45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5  M      43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
sns.countplot(x= 'Anaemic', data= report)
# Out:
# <Axes: xlabel='Anaemic', ylabel='count'>

# %%
sns.displot(report['%Red Pixel'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.barplot(x='Number', y='Hb', data= report)
# Out:
# <Axes: xlabel='Number', ylabel='Hb'>

# %%
sns.boxplot(x='Hb', y= 'Number', hue= 'Anaemic', data= report)
# Out:
# <Axes: xlabel='Hb', ylabel='Number'>

# %%
def get_gender(gender):
    if gender[0] =='M':
        return 'M'
    else:
        return 'F'

# %%
report['Sex'] = report['Sex'].apply(get_gender)

# %%
anaemic= pd.get_dummies(report['Anaemic'], drop_first= True)

# %%
report= pd.concat([report,anaemic], axis=1)
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic    Yes
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes   True
# 1         2   F     45.6033       28.1900      26.2067  13.5      No  False
# 2         3   F     45.0107       28.9677      26.0215  11.7      No  False
# 3         4   F     44.5398       28.9899      26.4703  13.5      No  False
# 4         5   M     43.2870       30.6972      26.0158  12.4      No  False
# ..      ...  ..         ...           ...          ...   ...     ...    ...
# 99      100   F     49.9999       29.2860      20.7141  14.5     Yes   True
# 100     101   M     42.2324       30.6757      27.0919   6.3     Yes   True
# 101     102   F     45.6064       31.9084      22.4852  12.7      No  False
# 102     103   M     45.2095       29.2769      25.5136  13.4      No  False
# 103     104   F     43.5706       29.8094      26.6199  12.2      No  False
#
# [104 rows x 8 columns]

# %%
report=report.drop(['Anaemic'],axis=1)

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb    Yes
# 0         1   M     43.2555       30.8421      25.9025   6.3   True
# 1         2   F     45.6033       28.1900      26.2067  13.5  False
# 2         3   F     45.0107       28.9677      26.0215  11.7  False
# 3         4   F     44.5398       28.9899      26.4703  13.5  False
# 4         5   M     43.2870       30.6972      26.0158  12.4  False
# ..      ...  ..         ...           ...          ...   ...    ...
# 99      100   F     49.9999       29.2860      20.7141  14.5   True
# 100     101   M     42.2324       30.6757      27.0919   6.3   True
# 101     102   F     45.6064       31.9084      22.4852  12.7  False
# 102     103   M     45.2095       29.2769      25.5136  13.4  False
# 103     104   F     43.5706       29.8094      26.6199  12.2  False
#
# [104 rows x 7 columns]

# %%
sns.stripplot(x='Yes', y='Hb', data=report, jitter=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Yes', ylabel='Hb'>

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb    Yes
# 0         1   M     43.2555       30.8421      25.9025   6.3   True
# 1         2   F     45.6033       28.1900      26.2067  13.5  False
# 2         3   F     45.0107       28.9677      26.0215  11.7  False
# 3         4   F     44.5398       28.9899      26.4703  13.5  False
# 4         5   M     43.2870       30.6972      26.0158  12.4  False
# ..      ...  ..         ...           ...          ...   ...    ...
# 99      100   F     49.9999       29.2860      20.7141  14.5   True
# 100     101   M     42.2324       30.6757      27.0919   6.3   True
# 101     102   F     45.6064       31.9084      22.4852  12.7  False
# 102     103   M     45.2095       29.2769      25.5136  13.4  False
# 103     104   F     43.5706       29.8094      26.6199  12.2  False
#
# [104 rows x 7 columns]

# %%
report[['Number','%Red Pixel','%Green pixel','%Blue pixel','Hb']].corr()
# Out:
#                 Number  %Red Pixel  %Green pixel  %Blue pixel        Hb
# Number        1.000000    0.286166     -0.077089    -0.345707 -0.019768
# %Red Pixel    0.286166    1.000000     -0.732003    -0.845764  0.424586
# %Green pixel -0.077089   -0.732003      1.000000     0.255589 -0.637340
# %Blue pixel  -0.345707   -0.845764      0.255589     1.000000 -0.103373
# Hb           -0.019768    0.424586     -0.637340    -0.103373  1.000000

# %%
sns.heatmap(report[['Number','%Red Pixel','%Green pixel','%Blue pixel','Hb']].corr())
# Out:
# <Axes: >

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb    Yes
# 0         1   M     43.2555       30.8421      25.9025   6.3   True
# 1         2   F     45.6033       28.1900      26.2067  13.5  False
# 2         3   F     45.0107       28.9677      26.0215  11.7  False
# 3         4   F     44.5398       28.9899      26.4703  13.5  False
# 4         5   M     43.2870       30.6972      26.0158  12.4  False
# ..      ...  ..         ...           ...          ...   ...    ...
# 99      100   F     49.9999       29.2860      20.7141  14.5   True
# 100     101   M     42.2324       30.6757      27.0919   6.3   True
# 101     102   F     45.6064       31.9084      22.4852  12.7  False
# 102     103   M     45.2095       29.2769      25.5136  13.4  False
# 103     104   F     43.5706       29.8094      26.6199  12.2  False
#
# [104 rows x 7 columns]

# %%
x=report.drop(['Sex'], axis=1)
y= report['Yes']

# %%
#from sklearn.model_selection import train_test_split

#x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.35, random_state=101)

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex4 import *
# Out:
# /tmp/ipykernel_18/1500229236.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
from tensorflow import keras
from tensorflow.keras import layers,callbacks

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)
my_model= keras.Sequential([
    layers.Dense(units=35, activation='relu', input_shape=[6]),
   # layers.Dropout(0.3),
    #layers.BatchNormalization(),
    layers.Dense(units=35, activation='relu'),
    #layers.Dropout(0.3),
    #layers.BatchNormalization(),
    layers.Dense(units=35, activation='relu'),
    #layers.Dropout(0.3),
    #layers.BatchNormalization(),
    layers.Dense(units=35, activation='relu'),
    #layers.Dropout(0.3),
    #layers.BatchNormalization(),
    layers.Dense(units=2)
])
q_1.check()
q_2.check()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Correct:
#
# The gap between these curves is quite small and the validation loss never increases, so it's more likely that the network is underfitting than overfitting. It would be worth experimenting with more capacity to see if that's the case.
# Correct:
#
# Now the validation loss begins to rise very early, while the training loss continues to decrease. This indicates that the network has begun to overfit. At this point, we would need to try something to prevent it, either by reducing the number of units or through a method like early stopping. (We'll see another in the next lesson!)

# %%
my_model.compile(
    optimizer='adam',
    loss='mae'
)

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb    Yes
# 0         1   M     43.2555       30.8421      25.9025   6.3   True
# 1         2   F     45.6033       28.1900      26.2067  13.5  False
# 2         3   F     45.0107       28.9677      26.0215  11.7  False
# 3         4   F     44.5398       28.9899      26.4703  13.5  False
# 4         5   M     43.2870       30.6972      26.0158  12.4  False
# ..      ...  ..         ...           ...          ...   ...    ...
# 99      100   F     49.9999       29.2860      20.7141  14.5   True
# 100     101   M     42.2324       30.6757      27.0919   6.3   True
# 101     102   F     45.6064       31.9084      22.4852  12.7  False
# 102     103   M     45.2095       29.2769      25.5136  13.4  False
# 103     104   F     43.5706       29.8094      26.6199  12.2  False
#
# [104 rows x 7 columns]

# %%
training= my_model.fit(x,y,
                      epochs=50,
                      batch_size=1
)
# Out:
# Epoch 1/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6169
# Epoch 2/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4033
# Epoch 3/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2906
# Epoch 4/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3063
# Epoch 5/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2764
# Epoch 6/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2502
# Epoch 7/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2299
# Epoch 8/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2624
# Epoch 9/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2393
# Epoch 10/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2102
# Epoch 11/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1989
# Epoch 12/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1825
# Epoch 13/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1879
# Epoch 14/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1667
# ...

# %%
activation_layer = layers.Activation('relu')

x = np.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
history_df = pd.DataFrame(training.history)
# Start the plot at epoch 5. You can change this to get a different view.
history_df.loc[5:, ['loss']].plot();
