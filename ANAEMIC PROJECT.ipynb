# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
report= pd.read_csv('/Users/HP/OneDrive/Desktop/archive/output.csv')

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3  F      45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5  M      43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
report1= report['%Green pixel']
report1
# Out:
# 0      30.8421
# 1      28.1900
# 2      28.9677
# 3      28.9899
# 4      30.6972
#         ...
# 99     29.2860
# 100    30.6757
# 101    31.9084
# 102    29.2769
# 103    29.8094
# Name: %Green pixel, Length: 104, dtype: float64

# %%
#104 rows x 7 columns

# %%
a= len(report1)
b= sum(report1)
average= b/a
average
# Out:
# 28.87550673076924

# %%
s= report.max()

# %%
r= report.min()

# %%
s['%Green pixel'] #Highest
# Out:
# 32.3681

# %%
r['%Green pixel'] #Lowest
# Out:
# 25.1403

# %%
report2= report['Sex'].value_counts()
report2
# Out:
# Sex
# M     29
# M     26
# F     26
# F     23
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
graph= sns.distplot(report['%Green pixel'],  kde= False, bins=20)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8920\1122451276.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   graph= sns.distplot(report['%Green pixel'],  kde= False, bins=20)

# %%
sns.jointplot(x='%Green pixel', y='%Red Pixel', data= report, kind= 'kde')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(report, kind='scatter')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
report['Anaemic'].value_counts()
# Out:
# Anaemic
# No     78
# Yes    26
# Name: count, dtype: int64

# %%
sns.distplot(report1)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8920\3172829229.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(report1)
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='%Green pixel', ylabel='Density'>

# %%
sns.pairplot(report,hue= 'Anaemic', palette='cool')
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.kdeplot(report['%Red Pixel'])
sns.rugplot(report['%Red Pixel'])
#sns.distplot(report['%Red Pixel'])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='%Red Pixel', ylabel='Density'>

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3  F      45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5  M      43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
report1= report['%Green pixel']
report2= report['Number']

# %%
plt.plot(report1,report2, 'b');
plt.plot(report2,report1, 'b')

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3  F      45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5  M      43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
report_edit= report.drop('Sex', axis= 1)
report_edit
# Out:
#      Number  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1     43.2555       30.8421      25.9025   6.3     Yes
# 1         2     45.6033       28.1900      26.2067  13.5      No
# 2         3     45.0107       28.9677      26.0215  11.7      No
# 3         4     44.5398       28.9899      26.4703  13.5      No
# 4         5     43.2870       30.6972      26.0158  12.4      No
# ..      ...         ...           ...          ...   ...     ...
# 99      100     49.9999       29.2860      20.7141  14.5     Yes
# 100     101     42.2324       30.6757      27.0919   6.3     Yes
# 101     102     45.6064       31.9084      22.4852  12.7      No
# 102     103     45.2095       29.2769      25.5136  13.4      No
# 103     104     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 6 columns]

# %%
report_edit
# Out:
#      Number  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1     43.2555       30.8421      25.9025   6.3     Yes
# 1         2     45.6033       28.1900      26.2067  13.5      No
# 2         3     45.0107       28.9677      26.0215  11.7      No
# 3         4     44.5398       28.9899      26.4703  13.5      No
# 4         5     43.2870       30.6972      26.0158  12.4      No
# ..      ...         ...           ...          ...   ...     ...
# 99      100     49.9999       29.2860      20.7141  14.5     Yes
# 100     101     42.2324       30.6757      27.0919   6.3     Yes
# 101     102     45.6064       31.9084      22.4852  12.7      No
# 102     103     45.2095       29.2769      25.5136  13.4      No
# 103     104     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 6 columns]

# %%
sns.pairplot(report_edit)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.distplot(report['Hb'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8920\2129399221.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(report['Hb'])
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Hb', ylabel='Density'>

# %%
sns.distplot(report['Number'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8920\1978528782.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(report['Number'])
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Number', ylabel='Density'>

# %%
sns.displot(report['Hb'])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(report['Hb'])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Hb', ylabel='Count'>

# %%
x= report.Number
x
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 99     100
# 100    101
# 101    102
# 102    103
# 103    104
# Name: Number, Length: 104, dtype: int64

# %%
y= report['%Green pixel']
y
# Out:
# 0      30.8421
# 1      28.1900
# 2      28.9677
# 3      28.9899
# 4      30.6972
#         ...
# 99     29.2860
# 100    30.6757
# 101    31.9084
# 102    29.2769
# 103    29.8094
# Name: %Green pixel, Length: 104, dtype: float64

# %%
plt.plot(y,x, 'b*-')
plt.xlabel('Number')
plt.ylabel('%Green pixel')
# Out:
# Text(0, 0.5, '%Green pixel')

# %%
#count plot sshows the graph of discreet data(yes/no, aphabets)
#estimator is used to give what you want. either mean or SD or maax e.t.c.
#orient='h' Horizontal
#orient='v' Vertical
#hue in boxplot is to further evaluate your data
#violinplot is used to get the distribution plot as well as the box plot
#split=True is to join two discreet values together
#stripplot 
#Swarmplot is a scattered violin plot
#plots=
#.pivot table  allows you to choose what you want for the column, index, and values
#clustermap add the value subtract by its minimum and divide the total by the maximum value
#standard_scale= 1: where ! is for columns and 0 forr rows

# %%
sns.clustermap?
# Out:
# Signature:
# sns.clustermap(
#     data,
#     *,
#     pivot_kws=None,
#     method='average',
#     metric='euclidean',
#     z_score=None,
#     standard_scale=None,
#     figsize=(10, 10),
#     cbar_kws=None,
#     row_cluster=True,
#     col_cluster=True,
#     row_linkage=None,
#     col_linkage=None,
#     row_colors=None,
#     col_colors=None,
#     mask=None,
#     dendrogram_ratio=0.2,
#     colors_ratio=0.03,
#     cbar_pos=(0.02, 0.8, 0.05, 0.18),
#     tree_kws=None,
#     **kwargs,
# )
# Docstring:
# Plot a matrix dataset as a hierarchically-clustered heatmap.
#
# This function requires scipy to be available.
#
# Parameters
# ----------
# data : 2D array-like
#     Rectangular data for clustering. Cannot contain NAs.
# pivot_kws : dict, optional
#     If `data` is a tidy dataframe, can provide keyword arguments for
#     pivot to create a rectangular dataframe.
# method : str, optional
#     Linkage method to use for calculating clusters. See
#     :func:`scipy.cluster.hierarchy.linkage` documentation for more
#     information.
# metric : str, optional
#     Distance metric to use for the data. See
#     :func:`scipy.spatial.distance.pdist` documentation for more options.
#     To use different metrics (or methods) for rows and columns, you may
#     construct each linkage matrix yourself and provide them as
#     `{row,col}_linkage`.
# z_score : int or None, optional
#     Either 0 (rows) or 1 (columns). Whether or not to calculate z-scores
#     for the rows or the columns. Z scores are: z = (x - mean)/std, so
#     values in each row (column) will get the mean of the row (column)
#     subtracted, then divided by the standard deviation of the row (column).
#     This ensures that each row (column) has mean of 0 and variance of 1.
# standard_scale : int or None, optional
#     Either 0 (rows) or 1 (columns). Whether or not to standardize that
#     dimension, meaning for each row or column, subtract the minimum and
#     divide each by its maximum.
# figsize : tuple of (width, height), optional
#     Overall size of the figure.
# cbar_kws : dict, optional
#     Keyword arguments to pass to `cbar_kws` in :func:`heatmap`, e.g. to
#     add a label to the colorbar.
# {row,col}_cluster : bool, optional
#     If ``True``, cluster the {rows, columns}.
# {row,col}_linkage : :class:`numpy.ndarray`, optional
#     Precomputed linkage matrix for the rows or columns. See
#     :func:`scipy.cluster.hierarchy.linkage` for specific formats.
# {row,col}_colors : list-like or pandas DataFrame/Series, optional
#     List of colors to label for either the rows or columns. Useful to evaluate
#     whether samples within a group are clustered together. Can use nested lists or
#     DataFrame for multiple color levels of labeling. If given as a
#     :class:`pandas.DataFrame` or :class:`pandas.Series`, labels for the colors are
#     extracted from the DataFrames column names or from the name of the Series.
#     DataFrame/Series colors are also matched to the data by their index, ensuring
#     colors are drawn in the correct order.
# mask : bool array or DataFrame, optional
#     If passed, data will not be shown in cells where `mask` is True.
#     Cells with missing values are automatically masked. Only used for
#     visualizing, not for calculating.
# {dendrogram,colors}_ratio : float, or pair of floats, optional
#     Proportion of the figure size devoted to the two marginal elements. If
#     a pair is given, they correspond to (row, col) ratios.
# cbar_pos : tuple of (left, bottom, width, height), optional
#     Position of the colorbar axes in the figure. Setting to ``None`` will
#     disable the colorbar.
# tree_kws : dict, optional
#     Parameters for the :class:`matplotlib.collections.LineCollection`
#     that is used to plot the lines of the dendrogram tree.
# kwargs : other keyword arguments
#     All other keyword arguments are passed to :func:`heatmap`.
#
# Returns
# -------
# :class:`ClusterGrid`
#     A :class:`ClusterGrid` instance.
#
# See Also
# --------
# heatmap : Plot rectangular data as a color-encoded matrix.
#
# Notes
# -----
# The returned object has a ``savefig`` method that should be used if you
# want to save the figure object without clipping the dendrograms.
#
# To access the reordered row indices, use:
# ``clustergrid.dendrogram_row.reordered_ind``
#
# Column indices, use:
# ``clustergrid.dendrogram_col.reordered_ind``
#
# Examples
# --------
#
# .. include:: ../docstrings/clustermap.rst
# File:      c:\users\hp\anaconda3\lib\site-packages\seaborn\matrix.py
# Type:      function

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3  F      45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5  M      43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
sns.countplot(x= 'Anaemic', data= report)
# Out:
# <Axes: xlabel='Anaemic', ylabel='count'>

# %%
sns.displot(report['%Red Pixel'])
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.barplot(x='Number', y='Hb', data= report)
# Out:
# <Axes: xlabel='Number', ylabel='Hb'>

# %%
sns.boxplot(x='Hb', y= 'Number', hue= 'Anaemic', data= report)
# Out:
# <Axes: xlabel='Hb', ylabel='Number'>

# %%
full_report=pd.read_csv('/Users/HP/OneDrive/Desktop/archive/output.csv')
full_report= full_report.head(100)

# %%
full_report1= sns.boxplot(x='Anaemic', y='Number', data= full_report)
full_report1
# Out:
# <Axes: xlabel='Anaemic', ylabel='Number'>

# %%
full_report
# Out:
#     Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0        1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1        2   F     45.6033       28.1900      26.2067  13.5      No
# 2        3  F      45.0107       28.9677      26.0215  11.7      No
# 3        4   F     44.5398       28.9899      26.4703  13.5      No
# 4        5  M      43.2870       30.6972      26.0158  12.4      No
# ..     ...  ..         ...           ...          ...   ...     ...
# 95      96   M     52.1540       26.0853      21.7607  16.0      No
# 96      97   F     51.5802       28.2678      20.1520  13.2      No
# 97      98   M     48.3681       26.9220      24.7099  12.5      No
# 98      99  M      47.3260       27.2780      25.3960  13.0      No
# 99     100  F      49.9999       29.2860      20.7141  14.5     Yes
#
# [100 rows x 7 columns]

# %%
def get_gender(gender):
    if gender[0].upper() =='M':
        return 'M'
    if gender[0].upper() =='F':
        return 'F'

# %%
report['Sex'] = report['Sex'].apply(get_gender)

# %%
full_report['Sex'] = report['Sex'].apply(get_gender)

# %%
full_report['Sex']
# Out:
# 0     M
# 1     F
# 2     F
# 3     F
# 4     M
#      ..
# 95    M
# 96    F
# 97    M
# 98    M
# 99    F
# Name: Sex, Length: 100, dtype: object

# %%
sex= full_report['Sex'].value_counts()
sex
# Out:
# Sex
# M    53
# F    47
# Name: count, dtype: int64

# %%
np.array(sex)
# Out:
# array([53, 47], dtype=int64)

# %%
sns.stripplot(x='Anaemic', y='Hb', data= full_report, jitter=True)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Anaemic', ylabel='Hb'>

# %%
full_report['Sex'].value_counts()
# Out:
# Sex
# M    53
# F    47
# Name: count, dtype: int64

# %%
male_report= full_report[(full_report['Sex']=='M ')]

# %%
male_report['Sex'].count()
# Out:
# 0

# %%
male_report2= full_report[(full_report['Sex']=='M')]

# %%
new_male_report= pd.concat([male_report,male_report2])
new_male_report
# Out:
#     Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0        1   M     43.2555       30.8421      25.9025   6.3     Yes
# 4        5   M     43.2870       30.6972      26.0158  12.4      No
# 5        6   M     45.0994       27.9645      26.9361  16.2      No
# 13      14   M     45.0484       31.1049      23.8467   9.0     Yes
# 14      15   M     46.9942       26.0496      26.9562  14.6      No
# 15      16   M     45.5842       28.7311      25.6848  14.0      No
# 24      25   M     45.6906       30.0735      24.2359   9.1     Yes
# 25      26   M     43.4098       31.2315      25.3586  12.9      No
# 27      28   M     44.3297       28.7617      26.9086  14.1      No
# 28      29   M     47.8913       27.0952      25.0135  14.6      No
# 29      30   M     42.2473       30.2089      27.5438  13.7      No
# 30      31   M     44.2572       29.6578      26.0850  12.9      No
# 31      32   M     48.6358       26.6982      24.6660  15.0      No
# 32      33   M     42.1652       29.3907      28.4441  13.4      No
# 33      34   M     45.4434       28.3301      26.2265  14.5      No
# 35      36   M     45.2588       28.0079      26.7333  12.6      No
# 37      38   M     47.2275       28.2526      24.5199  12.8      No
# 39      40   M     46.1449       27.7085      26.1466  14.1      No
# 40      41   M     41.7122       30.1452      28.1426  10.9      No
# 41      42   M     47.9777       26.7981      25.2242  16.3      No
# 42      43   M     46.7628       28.0180      25.2192  15.2      No
# 43      44   M     44.9526       28.4671      26.5803  13.1      No
# 44      45   M     44.1868       28.9764      26.8368  14.1      No
# 45      46   M     46.9428       27.2219      25.8353  13.3      No
# 46      47   M     48.8523       26.2003      24.9474  14.1      No
# 47      48   M     45.7581       27.2867      26.9553  11.8      No
# 48      49   M     48.5356       26.4917      24.9727  15.6      No
# 49      50   M     45.5833       27.6916      26.7252  11.7      No
# 50      51   M     45.9659       28.4015      25.6326  13.0      No
# 51      52   M     44.0418       28.5164      27.4418  11.9      No
# 52      53   M     43.9633       28.5978      27.4390  13.4      No
# 54      55   M     46.0477       28.6476      25.3047  14.4      No
# 55      56   M     46.2133       28.3358      25.4509  13.0      No
# 56      57   M     49.1475       28.2711      22.5813  12.6      No
# 57      58   M     45.7986       27.7309      26.4706  13.0      No
# 58      59   M     40.6395       32.1891      27.1714   2.8     Yes
# 63      64   M     43.4837       30.7106      25.8057  10.5     Yes
# 66      67   M     44.1609       29.5993      26.2399   9.5     Yes
# 71      72   M     41.1330       32.3681      26.4989  10.0     Yes
# 73      74   M     50.4976       28.8065      20.6960  11.1      No
# 74      75   M     44.7200       28.0357      27.2443  14.0      No
# 75      76   M     53.9113       26.3455      19.7433  14.5      No
# 83      84   M     45.4735       27.9181      26.6084  16.0      No
# 86      87   M     46.7979       28.1768      25.0253  14.0      No
# 87      88   M     46.5811       29.7082      23.7107  11.3      No
# 88      89   M     54.6478       25.8109      19.5413  15.2      No
# 89      90   M     48.8763       29.4806      21.6431  12.5      No
# 91      92   M     43.1425       30.2890      26.5686   9.5     Yes
# 92      93   M     49.5037       26.7716      23.7246  14.5      No
# 93      94   M     47.7549       26.2457      25.9994  15.2      No
# 95      96   M     52.1540       26.0853      21.7607  16.0      No
# 97      98   M     48.3681       26.9220      24.7099  12.5      No
# 98      99   M     47.3260       27.2780      25.3960  13.0      No

# %%
new_male_report['Sex'].count()
# Out:
# 53

# %%
report
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3   F     45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5   M     43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100   F     49.9999       29.2860      20.7141  14.5     Yes
# 100     101   M     42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103   M     45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
report[['Number','%Red Pixel','%Green pixel','%Blue pixel','Hb']].corr()
# Out:
#                 Number  %Red Pixel  %Green pixel  %Blue pixel        Hb
# Number        1.000000    0.286166     -0.077089    -0.345707 -0.019768
# %Red Pixel    0.286166    1.000000     -0.732003    -0.845764  0.424586
# %Green pixel -0.077089   -0.732003      1.000000     0.255589 -0.637340
# %Blue pixel  -0.345707   -0.845764      0.255589     1.000000 -0.103373
# Hb           -0.019768    0.424586     -0.637340    -0.103373  1.000000

# %%
sns.heatmap(report[['Number','%Red Pixel','%Green pixel','%Blue pixel','Hb']].corr())
# Out:
# <Axes: >
